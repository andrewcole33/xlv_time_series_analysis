# %% [markdown]
# # Module 4 Project: Financial Instrument Time Series Analysis - Techincal Notebook
# ### Andrew Cole

# %%
#Import necessary libraries, including Helper.py module

import ticker_cleaner
import Auto_ARIMA
import pandas as pd
import stationarity_check
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.tsa.stattools as TS
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
import statsmodels.api as sm;

import warnings

# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Gathering Financial Data and Visualizing Historic Movement

# %%
#Use ticker_cleaner module to perform all data gathering and organization into Pandas DF for operation.

xlv_monthly_mean = ticker_cleaner.yahoo_finance_clean('XLV')
xlv_monthly_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-444c67ba6de4> in <module>
#       1 #Use ticker_cleaner module to perform all data gathering and organization into Pandas DF for operation.
#       2
# ----> 3 xlv_monthly_mean = ticker_cleaner.yahoo_finance_clean('XLV')
#       4 xlv_monthly_mean
#
# ~/Desktop/chicago-102819-keep/mod_4_project/ticker_cleaner.py in yahoo_finance_clean(ticker)
#      16     ticker_monthly_mean = pd.DataFrame(ticker_hist_monthly.mean())
#      17
# ---> 18     return ticker_monthly_mean.reindex(index=xlv_monthly_mean.index[::-1])
#
# NameError: name 'xlv_monthly_mean' is not defined

# %%
# Plot the historic movement of XLV's Monthly Mean Closing Price

warnings.filterwarnings(action='always')
plt.style.use('ggplot')
fig = plt.figure(figsize = (16,9))
plt.plot(xlv_monthly_mean, linewidth = 3, label = 'Closing Price')
plt.title('XLV Monthly Mean Closing Price')
plt.legend()
plt.show();
plt.savefig('XLV_beginning_close_price')

# %% [markdown]
# ## Decomposition

# %%
# Use seasonal decomposition function from statsmodels library to seasonally decompose the XLV series after it has been log-transformed

decomposition = seasonal_decompose(np.log(xlv_monthly_mean))

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
#Visualize trend, seasonality, and residual distribution individually

plt.figure(figsize=(12,8))
plt.subplot(411)
plt.plot(xlv_monthly_mean, label='Original', color="blue")
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend', color="blue")
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality', color="blue")
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals', color="blue")
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ## Stationarity Check

# %%
# Take a one period difference of the means and perform a stationarity check(Dickey-Fuller Test). Null Hypothesis: The series is NOT stationary.

xlv_differenced_mean = xlv_monthly_mean.diff(periods = 1).dropna()
stationarity_check.stationarity_check(xlv_differenced_mean.Close)
# Out:
# Results of Dickey-Fuller Test
# Test Statistic                -1.139028e+01
# p-value                        8.099788e-21
# #Lags Used                     1.000000e+00
# Number of Observations Used    2.510000e+02
# Critical Value (1%)           -3.456674e+00
# Critical Value (5%)           -2.873125e+00
# Critical Value (10%)          -2.572944e+00
# dtype: float64

# %%
# We can reject the null hypothesis and say that the series is now stationary.

# %% [markdown]
# ## Model Optimization

# %%
#Plot ACF and PACF functions to get Autoregressive and Moving Average parameters 
fig, ax = plt.subplots(figsize = (16,3))
plot_acf(xlv_differenced_mean, ax = ax, lags = 12);

fig, ax = plt.subplots(figsize = (16,3))
plot_pacf(xlv_differenced_mean, ax=ax, lags = 12);

# %%
# Run a SARIMA model with order (1,1,2)x(1,1,2,12) to account for seasonality as well. 
mod = sm.tsa.statespace.SARIMAX(xlv_monthly_mean, trend='n', order=(1,1,2), seasonal_order=(1,1,2,12));
res = mod.fit();
res.summary()
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                  254
# Model:             SARIMAX(1, 1, 2)x(1, 1, 2, 12)   Log Likelihood                -408.767
# Date:                            Wed, 08 Jan 2020   AIC                            831.534
# Time:                                    13:14:51   BIC                            855.927
# Sample:                                01-01-2020   HQIC                           841.362
#                                      - 12-01-1998
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2883      0.489      0.589      0.556      -0.670       1.247
# ma.L1          0.0101      0.489      0.021      0.984      -0.948       0.968
# ma.L2         -0.1933      0.148     -1.304      0.192      -0.484       0.097
# ar.S.L12      -0.9996      0.066    -15.159      0.000      -1.129      -0.870
# ma.S.L12       0.1513      0.587      0.258      0.797      -0.999       1.301
# ma.S.L24      -0.8340      0.506     -1.650      0.099      -1.825       0.157
# sigma2         1.5771      0.812      1.941      0.052      -0.015       3.169
# ===================================================================================
# Ljung-Box (Q):                       31.27   Jarque-Bera (JB):               137.53
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.25   Skew:                             0.68
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.44
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Run a second SARIMA model with order (1,1,1)x(1,1,1,12)) to account for seasonality as well
mod = sm.tsa.statespace.SARIMAX(xlv_monthly_mean, trend='n', order=(1,1,1), seasonal_order=(1,1,1,12))
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                  254
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -412.091
# Date:                            Wed, 08 Jan 2020   AIC                            834.181
# Time:                                    13:14:52   BIC                            851.605
# Sample:                                01-01-2020   HQIC                           841.201
#                                      - 12-01-1998
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2001      0.169     -1.185      0.236      -0.531       0.131
# ma.L1          0.5177      0.155      3.347      0.001       0.215       0.821
# ar.S.L12      -0.0765      0.057     -1.352      0.176      -0.187       0.034
# ma.S.L12      -0.8335      0.062    -13.388      0.000      -0.955      -0.711
# sigma2         1.6752      0.104     16.145      0.000       1.472       1.879
# ===================================================================================
# Ljung-Box (Q):                       31.47   Jarque-Bera (JB):               135.86
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.26   Skew:                             0.71
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# #### Auto-ARIMA

# %%
# Utilizes the auto_arima function from Auto_ARIMA.py module to return the best parameter combination which returns the lowest AIC value
Auto_ARIMA.auto_arima()

# %%
# Create a copy DF for addition of forecasted values.
xlv_monthly_auto = xlv_monthly_mean.copy()

# %%
warnings.filterwarnings(action='once')
Auto_ARIMA = sm.tsa.statespace.SARIMAX(xlv_monthly_auto.Close,
                                       order = (2,2,2),
                                       seasonal_order = (1,1,2,12),
                                       enforce_stationarity = False,
                                       enforce_invertability = False)
output_auto = Auto_ARIMA.fit()
print(output_auto.summary().tables[1])
output_auto.summary()
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6903      0.093     -7.404      0.000      -0.873      -0.508
# ar.L2          0.2079      0.086      2.426      0.015       0.040       0.376
# ma.L1         -0.0583      0.277     -0.211      0.833      -0.601       0.484
# ma.L2         -0.9375      0.286     -3.273      0.001      -1.499      -0.376
# ar.S.L12      -0.4889      0.106     -4.615      0.000      -0.697      -0.281
# ma.S.L12      -0.3306      0.140     -2.361      0.018      -0.605      -0.056
# ma.S.L24      -0.5061      0.111     -4.571      0.000      -0.723      -0.289
# sigma2         1.2796      0.386      3.317      0.001       0.523       2.036
# ==============================================================================
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                  254
# Model:             SARIMAX(2, 2, 2)x(1, 1, 2, 12)   Log Likelihood                -336.263
# Date:                            Wed, 08 Jan 2020   AIC                            688.526
# Time:                                    13:16:34   BIC                            715.416
# Sample:                                01-01-2020   HQIC                           699.393
#                                      - 12-01-1998
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6903      0.093     -7.404      0.000      -0.873      -0.508
# ar.L2          0.2079      0.086      2.426      0.015       0.040       0.376
# ma.L1         -0.0583      0.277     -0.211      0.833      -0.601       0.484
# ma.L2         -0.9375      0.286     -3.273      0.001      -1.499      -0.376
# ar.S.L12      -0.4889      0.106     -4.615      0.000      -0.697      -0.281
# ma.S.L12      -0.3306      0.140     -2.361      0.018      -0.605      -0.056
# ma.S.L24      -0.5061      0.111     -4.571      0.000      -0.723      -0.289
# sigma2         1.2796      0.386      3.317      0.001       0.523       2.036
# ===================================================================================
# Ljung-Box (Q):                       18.53   Jarque-Bera (JB):               103.09
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.40   Skew:                             0.83
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.97
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
xlv_monthly_auto['Close_P'] = output_auto.predict(start = 225, end = 254, dynamic = False)
xlv_monthly_auto[['Close', 'Close_P']].plot(figsize = (16,9))
plt.legend(loc = 'upper left')
plt.show()

# %%
xlv_monthly_auto
# Out:
#                  Close    Close_P
# Date
# 2020-01-01  101.874000        NaN
# 2019-12-01  100.354762        NaN
# 2019-11-01   95.596500        NaN
# 2019-10-01   90.148696        NaN
# 2019-09-01   89.694500        NaN
# ...                ...        ...
# 1999-04-01   21.752857  21.872696
# 1999-03-01   20.773913  21.636264
# 1999-02-01   20.173684  20.866940
# 1999-01-01   19.944737  20.389595
# 1998-12-01   19.021429  19.503378
#
# [254 rows x 2 columns]
